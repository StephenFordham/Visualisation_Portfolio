# %%
fig, (ax, ax2, ax3) = plt.subplots(1,3, figsize=(20,8), sharex=True, sharey=True)



sns.set_palette(sns.color_palette(colors2))

sns.stripplot(x='Insertion Element', y='Plasmid Size', data=df,
              hue=df['Plasmid Family > 5'], 
              alpha=0.6, s=6,
             edgecolor='black',
             linewidth=0.3,
             jitter=0.2,
            ax=ax) 

sns.boxplot(x='Insertion Element', y='Plasmid Size', data=df, color='white', ax=ax)


leg = ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3, title="Plasmid Replicon Family")





sns.set_palette(sns.color_palette(colors))

sns.stripplot(x='Insertion Element', y='Plasmid Size', data=df,
              hue=df['Country > 5'], 
              alpha=0.6, s=6,
             edgecolor='black',
             linewidth=0.3,
             jitter=0.2,
              ax=ax2)


sns.boxplot(x='Insertion Element', y='Plasmid Size', data=df, color='white', ax=ax2)


leg2 = ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3, title="Country")


sns.stripplot(x='Insertion Element', y='Plasmid Size', data=df,
              hue=df['Sample Type'], 
              alpha=0.6, s=6,
             edgecolor='black',
             linewidth=0.3,
             jitter=0.2,
              ax=ax3)

leg3 = ax3.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3, title="Sample Source")

text1 = ax.annotate("A", xy=(0.05, 0.95), xycoords="axes fraction")
text2 = ax2.annotate("B", xy=(0.05, 0.95), xycoords="axes fraction")
text3 = ax3.annotate("C", xy=(0.05, 0.95), xycoords="axes fraction")
text1.set_fontsize(12)
text2.set_fontsize(12)
text3.set_fontsize(12)

plt.suptitle('Insertion Element versus Plasmid Size for Country and Plasmid Replicon Type', fontsize=16)

ax.set_title('hue = Plasmid Replicon Family')
ax2.set_title('hue = Country')
ax3.set_title('hue = Sample Source')

plt.show() 

fig.savefig('insertion_stripplot_adjusted_v3.jpg', bbox_inches='tight')
