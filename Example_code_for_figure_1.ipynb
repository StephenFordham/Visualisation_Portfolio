# %%
fig3 = plt.figure(constrained_layout=True, figsize=(16, 11))
gs = fig3.add_gridspec(2, 4)
ax = fig3.add_subplot(gs[0, :])
font_color = '#525252'
colors = ['#f47e7a', '#B1A9A7']



ax.text(-0.05, 0.95, 'A.',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='black', fontsize=15)



ax.text(-0.05, -0.2, 'B.',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='black', fontsize=15)


fig3.suptitle('Insertion Sequence Detection in plasmids found' 
              'in $\it{Klebsiella\ pneumoniae}$ \nversus other species', size=18, y=1.12)


df.iloc[:, :2].plot.barh(align='center', stacked=True, color=colors, ax=ax)




for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(12)
    
legend = ax.legend(loc='center',
       frameon=False,
       bbox_to_anchor=(0., 1.02, 1., .102), 
       mode='expand', 
       ncol=2, 
       borderaxespad=-.46,
       prop={'size': 10})

for text in legend.get_texts():
    plt.setp(text, color=font_color) # legend font color
    

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y,  = p.get_xy() 
    ax.text(x+width/2, 
            y+height/2, 
            '{:.0f}' .format(width), 
            horizontalalignment='center', 
            verticalalignment='center',
            color='white',
            fontsize=10,
            )


for p, i in zip(ax.patches, kp_pc):
    width, height = p.get_width(), p.get_height()
    x, y,  = p.get_xy() 
    ax.text(x+width/1.2, 
            y+height/2, 
            '({:.2f}%)'.format(i), 
#             '{:.1f}% {:.1f}%'.format(i,z),
            horizontalalignment='center', 
            verticalalignment='center',
            color='black',
            fontsize=10,
            )

ax.set_xlabel('Number of bacterial isolates carrying plasmids encoding IS elements',
              fontdict= { 'fontsize': 12} )
ax.set_ylabel('Insertion Sequence Element', fontdict= { 'fontsize': 12})

    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

#######################################
ax2 = fig3.add_subplot(gs[1, 0])
ax2.set_title('ISKpn25',fontdict= { 'fontsize': 12, 'fontweight':'bold'})

values = iskpn25_bar['Percentage'].to_list()
clrs = ['white' if (x < max(values)) else '#f47e7a' for x in values ]
ax2 = sns.barplot(x=['$\it{}$'.format(x) for x in iskpn25_bar.index], y=sorted(iskpn25_bar['Percentage'], reverse=True),
                  data=iskpn25_bar, edgecolor='black', linewidth=1.5, palette=clrs)

ax2.set_ylabel('Percentage (%)', fontdict= { 'fontsize': 12})
ax2.set_xlabel('Bacterial Species', fontdict= { 'fontsize': 12})
ax2.xaxis.set_label_coords(0.5, -0.409)
# ax2.set(xlabel='Bacterial Species')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
 



ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90);


#######################################
ax3 = fig3.add_subplot(gs[1:, 1])

ax3.set_title('ISKpn26',fontdict= { 'fontsize': 12, 'fontweight':'bold'})

values = iskpn26_bar['Percentage'].to_list()
clrs = ['white' if (x < max(values)) else '#f47e7a' for x in values ]
ax3 = sns.barplot(x=['$\it{}$'.format(x) for x in iskpn26_bar.index], y=sorted(iskpn26_bar['Percentage'], reverse=True),
                  data=iskpn26_bar, edgecolor='black', linewidth=1.5, palette=clrs)

ax3.set_xlabel('Bacterial Species', fontdict= { 'fontsize': 12})
ax3.xaxis.set_label_coords(0.5, -0.409)
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)




ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90);



#######################################
ax4 = fig3.add_subplot(gs[-1, 2])

ax4.set_title('ISKpn14',fontdict= { 'fontsize': 12, 'fontweight':'bold'})

values = iskpn14_bar['Percentage'].to_list()
clrs = ['white' if (x < max(values)) else '#f47e7a' for x in values ]
ax4 = sns.barplot(x=['$\it{}$'.format(x) for x in iskpn14_bar.index], y=sorted(iskpn14_bar['Percentage'], reverse=True),
                  data=iskpn14_bar, edgecolor='black', linewidth=1.5, palette=clrs)

ax4.set_xlabel('Bacterial Species', fontdict= { 'fontsize': 12})
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)


ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90);


#######################################

ax5 = fig3.add_subplot(gs[-1, 3])

ax5.set_title('IS903B',fontdict= { 'fontsize': 12, 'fontweight':'bold'})

values = is903b_bar['Percentage'].to_list()
clrs = ['white' if (x < max(values)) else '#f47e7a' for x in values ]
ax5 = sns.barplot(x=['$\it{}$'.format(x) for x in is903b_bar.index], y=sorted(is903b_bar['Percentage'], reverse=True),
                  data=is903b_bar, edgecolor='black', linewidth=1.5, palette=clrs)

ax5.set_xlabel('Bacterial Species', fontdict= { 'fontsize': 12})
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
 


ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90);

fig3.savefig('Klebsiella_versus_other_species_proportional_assignment.jpeg', bbox_inches='tight')
